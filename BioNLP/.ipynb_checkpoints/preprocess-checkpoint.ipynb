# %%
import os
import glob
import nltk.data
import re

# %%
nltk.download()

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-58-d65bba0f5a71> in <module>()
# ----> 1 tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
#
# C:\Users\seds0\Anaconda\lib\site-packages\nltk\data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     779
#     780     # Load the resource.
# --> 781     opened_resource = _open(resource_url)
#     782
#     783     if format == 'raw':
#
# C:\Users\seds0\Anaconda\lib\site-packages\nltk\data.py in _open(resource_url)
#     893
#     894     if protocol is None or protocol.lower() == 'nltk':
# --> 895         return find(path_, path + ['']).open()
#     896     elif protocol.lower() == 'file':
#     897         # urllib might not use mode='rb', so handle this one ourselves:
#
# C:\Users\seds0\Anaconda\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     622     sep = '*'*70
#     623     resource_not_found = '\n%s\n%s\n%s' % (sep, msg, sep)
# --> 624     raise LookupError(resource_not_found)
#     625
#     626 def retrieve(resource_url, filename=None, verbose=True):
#
# LookupError:
# **********************************************************************
#   Resource u'tokenizers/punkt/english.pickle' not found.  Please
#   use the NLTK Downloader to obtain the resource:  >>>
#   nltk.download()
#   Searched in:
#     - 'C:\\Users\\seds0/nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - 'C:\\Users\\seds0\\Anaconda\\nltk_data'
#     - 'C:\\Users\\seds0\\Anaconda\\lib\\nltk_data'
#     - 'C:\\Users\\seds0\\AppData\\Roaming\\nltk_data'
#     - u''
# **********************************************************************

# %%
def get_entity_dict(a1_file):
    entity_dict={}
    with open(a1_file, 'r') as reader:
        for line in reader:
            tab_del_list=line.strip().split("\t")
            entity_id = tab_del_list[0]
            entity_type = tab_del_list[1].split(' ')[0]
            start_off = int(tab_del_list[1].split(' ')[1])
            end_off = int(tab_del_list[1].split(' ')[2])
            entity_name = tab_del_list[2]
            
            #print entity_id, entity_type,start_off, end_off,entity_name
            if entity_id not in entity_dict:
                entity_dict[entity_id] = [entity_type, start_off, end_off,entity_name]
            elif entity_id in entity_dict:
                raise Exception('key error')
                
    return entity_dict

# %%
def get_event_dict(a2_file):
    event_dict={}
    with open(a2_file, 'r') as reader:
        for line in reader:
            if 'E' in line.strip().split('\t')[0]:
                event_id = line.strip().split('\t')[0]
                if event_id not in event_dict:
                    event_dict[event_id]=line.strip().split('\t')[1].split(' ')
                else:
                    raise Exception('key error')  

                
    return event_dict

# %%
def extract_entity_relation_triple(line, event_dict, entity_dict):
    if 'E' in line.split('\t')[0]:
        #print line.split('\t')[0],line.split('\t')[1].split(' ')
        if len(line.split('\t')[1].split(' '))>=3:
            theme_string = line.split('\t')[1].split(' ')[1].split(':')[1]
            cause_string = line.split('\t')[1].split(' ')[2].split(':')[1]
            
            #print line
            if 'E' in theme_string:
                effect = event_dict[theme_string][0].split(':')[0]
                result_entity_id = event_dict[theme_string][1].split(':')[1]

                if 'E' in cause_string:
                    cause_entity_id = event_dict[cause_string][1].split(':')[1]
                    if 'T' in cause_entity_id and 'T' in result_entity_id:
                        return entity_dict[cause_entity_id][3] , effect ,  entity_dict[result_entity_id][3]
                
                elif 'E' not in cause_string :
                    cause_entity_id = line.split('\t')[1].split(' ')[2].split(':')[1]
                    if 'T' in result_entity_id:
                        return entity_dict[cause_entity_id][3] , effect , entity_dict[result_entity_id][3]

            elif 'E' in cause_string:
                    effect = line.split('\t')[1].split(' ')[0].split(':')[0]
                    result_entity_id = theme_string
                    cause_entity_id = event_dict[cause_string][1].split(':')[1]
                    
                    if 'T' in cause_entity_id: 
                        return entity_dict[cause_entity_id][3] , effect , entity_dict[result_entity_id][3]


def extract_entity_relation_triple_in_a2_file(a2_file,event_dict,entity_dict):
    result_list =[]
    
    with open(a2_file, 'r') as reader:
        for line in reader:
            line = line.strip()
            result = extract_entity_relation_triple(line,event_dict,entity_dict)
            if result is not None:
                result_list.append(result)
                
    return result_list
             
    
    
def preprocess(text , a1_file, a2_file):
    entity_dict = get_entity_dict(a1_file)
    event_dict = get_event_dict(a2_file)
    entity_relation_triple_list = extract_entity_relation_triple_in_a2_file(a2_file,event_dict,entity_dict)
    return entity_relation_triple_list

# %%
text = './data/BioNLP-ST-2013_GE_train_data_rev3/PMC-2889865-06-Discussion.txt'
a1 = './data/BioNLP-ST-2013_GE_train_data_rev3/PMC-2889865-06-Discussion.a1'
a2 = './data/BioNLP-ST-2013_GE_train_data_rev3/PMC-2889865-06-Discussion.a2'

# %%
preprocess(text,a1, a2)
# Out:
# [('IL-2', 'Gene_expression', 'IL-2'),
#  ('IL-2', 'Localization', 'IL-2'),
#  ('Bcl10', 'Protein_catabolism', 'Bcl10')]

# %%
dataset_folder = './data/BioNLP-ST-2013_GE_train_data_rev3/'

# %%
file_list = list(set(map(lambda x:x.split('.')[0],os.listdir(dataset_folder))))
file_list.remove('LICENSE')
file_list.remove('README')
path_list = map(lambda x:dataset_folder+x , file_list)

# %%
total_list=[]
for path in path_list:
    text = path+'.txt'
    a1_file = path+'.a1'
    a2_file = path+'.a2'
    total_list.extend(preprocess(text,a1_file, a2_file))

# %%
total_list
# Out:
# [('IL-2', 'Gene_expression', 'IL-2'),
#  ('IL-2', 'Localization', 'IL-2'),
#  ('Bcl10', 'Protein_catabolism', 'Bcl10'),
#  ('PKCalpha', 'Phosphorylation', 'p65'),
#  ('Foxp3', 'Binding', 'CREB-1'),
#  ('Foxp3', 'Binding', 'activating transcription factor 2'),
#  ('p300', 'Transcription', 'Gal4-BD-CREB-1'),
#  ('Foxp3', 'Positive_regulation', 'Gal4-BD-CREB-1'),
#  ('Foxp3', 'Positive_regulation', 'Gal4-BD-CREB-1'),
#  ('p300', 'Binding', 'p300'),
#  ('Foxp3', 'Binding', 'p300'),
#  ('Foxp3', 'Binding', 'p300'),
#  ('LMP1', 'Positive_regulation', 'Akt'),
#  ('Akt', 'Negative_regulation', 'FoxO1'),
#  ('STAT4', 'Gene_expression', 'IL-10'),
#  ('STAT4', 'Gene_expression', 'IFN-gamma'),
#  ('STAT4', 'Gene_expression', 'IL-4'),
#  ('STAT4', 'Gene_expression', 'IL-10'),
#  ('STAT4', 'Gene_expression', 'IL-10'),
#  ('IL-12', 'Gene_expression', 'IL-10'),
#  ('OVA', 'Gene_expression', 'IL-10'),
#  ('STAT6', 'Gene_expression', 'IL-4'),
#  ('STAT6', 'Gene_expression', 'IL-10'),
#  ('STAT4', 'Gene_expression', 'IL-10'),
#  ('IFN-gamma', 'Regulation', 'IL-12'),
#  ('IFN-gamma', 'Gene_expression', 'IL-10'),
#  ('IFN-gamma', 'Localization', 'IL-4'),
#  ('IL-4', 'Gene_expression', 'IL-10'),
#  ('STAT4', 'Gene_expression', 'IL-10'),
#  ('STAT6', 'Gene_expression', 'IL-10'),
#  ('ERK1', 'Positive_regulation', 'p38'),
#  ('ERK2', 'Positive_regulation', 'p38'),
#  ('ERK1', 'Positive_regulation', 'GSK3beta'),
#  ('ERK2', 'Positive_regulation', 'GSK3beta'),
#  ('IL-12', 'Positive_regulation', 'ERK1'),
#  ('IL-12', 'Positive_regulation', 'ERK2'),
#  ('ERK1', 'Positive_regulation', 'IL-10'),
#  ('ERK2', 'Positive_regulation', 'IL-10'),
#  ('MEK5', 'Positive_regulation', 'ERK5'),
#  ('MEK1', 'Positive_regulation', 'ERK1'),
#  ('MEK2', 'Positive_regulation', 'ERK1'),
#  ('MEK1', 'Positive_regulation', 'ERK2'),
#  ('MEK2', 'Positive_regulation', 'ERK2'),
#  ('p38 MAPK', 'Gene_expression', 'IL-10'),
#  ('GSK3beta', 'Gene_expression', 'IL-10'),
#  ('IL-12', 'Gene_expression', 'IL-10'),
#  ('ERK1', 'Gene_expression', 'IL-10'),
#  ('ERK2', 'Gene_expression', 'IL-10'),
#  ('STAT-4', 'Gene_expression', 'IL-10'),
#  ('IL-12', 'Positive_regulation', 'STAT-4'),
#  ('ERK1', 'Gene_expression', 'IL-10'),
#  ('ERK2', 'Gene_expression', 'IL-10'),
#  ('IL-10', 'Gene_expression', 'IL-10'),
#  ('STAT4', 'Positive_regulation', 'IL-10'),
#  ('IL-12', 'Positive_regulation', 'IL-10'),
#  ('IL-12', 'Gene_expression', 'IL-10'),
#  ('IFN-gamma', 'Positive_regulation', 'IL-10'),
#  ('IL-12', 'Gene_expression', 'IL-10'),
#  ('IFN-gamma', 'Positive_regulation', 'IL-10'),
#  ('IL-12', 'Positive_regulation', 'IL-10'),
#  ('ERK1', 'Gene_expression', 'IL-10'),
#  ('ERK2', 'Gene_expression', 'IL-10'),
#  ('IL-12', 'Gene_expression', 'Gata-3'),
#  ('IL-12', 'Gene_expression', 'c-maf'),
#  ('ERK', 'Gene_expression', 'c-maf'),
#  ('ERK', 'Positive_regulation', 'IL-10'),
#  ('c-Maf', 'Gene_expression', 'IL-10'),
#  ('ERK1', 'Gene_expression', 'IL-10'),
#  ('ERK2', 'Gene_expression', 'IL-10'),
#  ('IL-12', 'Gene_expression', 'IL-10'),
#  ('IL-12', 'Gene_expression', 'IL-10'),
#  ('IKKbeta', 'Phosphorylation', 'p65'),
#  ('IKKbeta', 'Phosphorylation', 'p65'),
#  ('PKCalpha', 'Transcription', 'IL-1alpha'),
#  ('PKCalpha', 'Transcription', 'iNOS'),
#  ('PKCalpha', 'Transcription', 'TNFalpha'),
#  ('LMP1', 'Positive_regulation', 'IL15'),
#  ('LMP1', 'Positive_regulation', 'IFNgamma'),
#  ('IL10', 'Positive_regulation', 'Stat3'),
#  ('IL10', 'Positive_regulation', 'Stat3'),
#  ('LMP1', 'Positive_regulation', 'IL10'),
#  ('LMP1', 'Positive_regulation', 'IL10'),
#  ('IL10', 'Positive_regulation', 'pStat3'),
#  ('pStat3', 'Localization', 'pStat3'),
#  ('Pam3CYS', 'Gene_expression', 'IFNgamma'),
#  ('Sharpin', 'Negative_regulation', 'Sharpin'),
#  ('IL-12', 'Gene_expression', 'IL-10'),
#  ('IL-12', 'Gene_expression', 'IL-10'),
#  ('IL-12', 'Positive_regulation', 'IL-10'),
#  ('IL-12p40', 'Positive_regulation', 'IL-10'),
#  ('IL-12', 'Gene_expression', 'IL-10'),
#  ('IL-12', 'Gene_expression', 'IL-10'),
#  ('OVA', 'Gene_expression', 'IL-10'),
#  ('IL-12', 'Gene_expression', 'IL-10'),
#  ('IL-12', 'Gene_expression', 'IL-10'),
#  ('PKCalpha', 'Phosphorylation', 'p65'),
#  ('PKCalpha', 'Phosphorylation', 'p65'),
#  ('PKCalpha', 'Phosphorylation', 'p65'),
#  ('PKCalpha', 'Phosphorylation', 'p65'),
#  ('PKCalpha siRNA', 'Gene_expression', 'PKCalpha'),
#  ('Foxp3', 'Localization', 'Foxp3'),
#  ('Foxp3', 'Binding', 'Foxp3'),
#  ('Sharpin', 'Ubiquitination', 'RIP1'),
#  ('Sharpin', 'Ubiquitination', 'NEMO'),
#  ('HOIP', 'Positive_regulation', 'IKKgamma'),
#  ('IKKgamma', 'Negative_regulation', 'IKKgamma'),
#  ('IKKgamma', 'Negative_regulation', 'IKKgamma'),
#  ('IKKgamma', 'Positive_regulation', 'IKKgamma'),
#  ('IKKgamma', 'Positive_regulation', 'IKKgamma'),
#  ('HOIP', 'Binding', 'CD40'),
#  ('HOIP', 'Binding', 'CD40'),
#  ('TRAF2', 'Binding', 'HOIP'),
#  ('TRAF2', 'Binding', 'HOIP'),
#  ('SHARPIN', 'Transcription', 'IL6'),
#  ('SHARPIN', 'Transcription', 'GMCSF'),
#  ('SHARPIN', 'Gene_expression', 'IL6'),
#  ('SHARPIN', 'Gene_expression', 'GMCSF'),
#  ('IL4', 'Phosphorylation', 'Stat6'),
#  ('ERK1', 'Gene_expression', 'IL-10'),
#  ('ERK2', 'Gene_expression', 'IL-10'),
#  ('ERK1', 'Gene_expression', 'IL-10'),
#  ('ERK2', 'Gene_expression', 'IL-10'),
#  ('ERK1', 'Gene_expression', 'IL-10'),
#  ('ERK2', 'Gene_expression', 'IL-10'),
#  ('MEK', 'Gene_expression', 'IL-10'),
#  ('OVA', 'Gene_expression', 'IL-10'),
#  ('Foxp3', 'Binding', 'Foxp3'),
#  ('Foxp3', 'Localization', 'Foxp3'),
#  ('Foxp3', 'Binding', 'Foxp3'),
#  ('Foxp3', 'Negative_regulation', 'Foxp3'),
#  ('Tax', 'Gene_expression', 'Foxp3'),
#  ('Foxp3', 'Positive_regulation', 'IL-2'),
#  ('T-bet', 'Gene_expression', 'interferon (IFN) gamma'),
#  ('Eomesodermin', 'Gene_expression', 'interferon (IFN) gamma'),
#  ('Runx3', 'Gene_expression', 'Eomes'),
#  ('Runx3', 'Gene_expression', 'IFN-gamma'),
#  ('Runx3', 'Gene_expression', 'perforin'),
#  ('Runx3', 'Gene_expression', 'granzyme B'),
#  ('LMP1', 'Gene_expression', 'IL10'),
#  ('STAT4', 'Gene_expression', 'Interleukin-10'),
#  ('ERK', 'Gene_expression', 'Interleukin-10'),
#  ('IL-12', 'Positive_regulation', 'STAT4'),
#  ('ERK1', 'Gene_expression', 'IL-10'),
#  ('ERK2', 'Gene_expression', 'IL-10'),
#  ('Runx3', 'Gene_expression', 'Eomes'),
#  ('Runx3', 'Gene_expression', 'perforin'),
#  ('Runx3', 'Gene_expression', 'granzyme B'),
#  ('Runx3', 'Gene_expression', 'IFN-gamma'),
#  ('T-bet', 'Gene_expression', 'IFN-gamma'),
#  ('Runx3', 'Gene_expression', 'Eomes'),
#  ('Runx3', 'Gene_expression', 'perforin'),
#  ('Runx3', 'Gene_expression', 'granzyme B'),
#  ('Runx3', 'Gene_expression', 'IFN-gamma'),
#  ('Eomes', 'Gene_expression', 'IFN-gamma'),
#  ('Runx3', 'Gene_expression', 'perforin'),
#  ('Eomes', 'Gene_expression', 'perforin'),
#  ('T-bet', 'Gene_expression', 'perforin'),
#  ('T-bet', 'Gene_expression', 'Gzmb'),
#  ('T-bet', 'Gene_expression', 'granzyme B'),
#  ('dominant negative PKCalpha', 'Phosphorylation', 'p65'),
#  ('dominant negative PKCalpha', 'Phosphorylation', 'p65'),
#  ('TNFalpha', 'Phosphorylation', 'p65'),
#  ('PKCalpha', 'Phosphorylation', 'p65'),
#  ('ubiquitin', 'Protein_catabolism', 'p65'),
#  ('p65', 'Binding', 'p65'),
#  ('IKKalpha', 'Gene_expression', 'p52'),
#  ('p65', 'Positive_regulation', 'p65'),
#  ('LMP1', 'Gene_expression', 'IL10'),
#  ('IL10', 'Positive_regulation', 'Stat3'),
#  ('LMP1', 'Positive_regulation', 'Akt'),
#  ('LMP1', 'Positive_regulation', 'cRel'),
#  ('CD40', 'Negative_regulation', 'p27'),
#  ('pAkt', 'Phosphorylation', 'GSK3'),
#  ('pAkt', 'Negative_regulation', 'GSK3'),
#  ('Akt', 'Negative_regulation', 'Fox01'),
#  ('FoxO1', 'Gene_expression', 'bcl6'),
#  ('LMP1', 'Gene_expression', 'LMP1'),
#  ('bcl6', 'Gene_expression', 'LMP1'),
#  ('LMP1', 'Gene_expression', 'bcl6'),
#  ('bcl6', 'Gene_expression', 'bcl6'),
#  ('Fox01', 'Regulation', 'bcl6'),
#  ('Runx3', 'Positive_regulation', 'Eomes'),
#  ('Runx3', 'Positive_regulation', 'granzyme B'),
#  ('Runx3', 'Positive_regulation', 'perforin'),
#  ('Runx3', 'Positive_regulation', 'IFN-gamma'),
#  ('Runx3', 'Gene_expression', 'granzyme B'),
#  ('Runx3', 'Gene_expression', 'perforin'),
#  ('Runx3', 'Gene_expression', 'IFN-gamma'),
#  ('Runx3', 'Gene_expression', 'TNF'),
#  ('Runx3', 'Gene_expression', 'IL-2'),
#  ('Runx3', 'Gene_expression', 'IFN-gamma'),
#  ('Runx1', 'Positive_regulation', 'TNF'),
#  ('Runx1', 'Positive_regulation', 'IL-2'),
#  ('Runx3', 'Gene_expression', 'IFN-gamma'),
#  ('T-bet', 'Gene_expression', 'IFN-gamma'),
#  ('Eomes', 'Gene_expression', 'IFN-gamma'),
#  ('T-bet', 'Gene_expression', 'IFN-gamma'),
#  ('T-bet', 'Gene_expression', 'perforin'),
#  ('Eomes', 'Gene_expression', 'perforin'),
#  ('T-bet', 'Gene_expression', 'granzyme B'),
#  ('Eomes', 'Gene_expression', 'perforin'),
#  ('T-bet', 'Positive_regulation', 'Gzmb'),
#  ('Eomes', 'Positive_regulation', 'Prf1'),
#  ('T-bet', 'Gene_expression', 'perforin'),
#  ('Eo-VP16', 'Gene_expression', 'granzyme B'),
#  ('Eomes', 'Gene_expression', 'perforin'),
#  ('Runx3', 'Gene_expression', 'perforin'),
#  ('Runx3', 'Positive_regulation', 'Eomes'),
#  ('T-bet', 'Regulation', 'Ifng'),
#  ('Eomes', 'Regulation', 'Ifng'),
#  ('T-bet', 'Regulation', 'Prf1'),
#  ('Eomes', 'Regulation', 'Prf1'),
#  ('T-bet', 'Regulation', 'GzmB'),
#  ('Eomes', 'Regulation', 'GzmB'),
#  ('T-bet', 'Gene_expression', 'IFN-gamma'),
#  ('Eomes', 'Gene_expression', 'perforin'),
#  ('Foxp3', 'Binding', 'p300'),
#  ('Foxp3', 'Binding', 'Foxp3'),
#  ('Foxp3', 'Binding', 'Foxp3'),
#  ('Tax', 'Binding', 'Tax'),
#  ('Tax', 'Gene_expression', 'Foxp3'),
#  ('Foxp3', 'Binding', 'CBP'),
#  ('Foxp3', 'Binding', 'p300'),
#  ('CD40', 'Phosphorylation', 'IkappaBalpha'),
#  ('CD40', 'Protein_catabolism', 'IkappaBalpha'),
#  ('type I IFN',
#   'Positive_regulation',
#   'signal transducer and activator of transcription (STAT)1'),
#  ('IFN-gamma',
#   'Positive_regulation',
#   'signal transducer and activator of transcription (STAT)1'),
#  ('signal transducer and activator of transcription (STAT)1',
#   'Gene_expression',
#   'IFN-gamma'),
#  ('STAT3', 'Gene_expression', 'RORgammat'),
#  ('IL-12', 'Gene_expression', 'IFN-gamma'),
#  ('ERK1', 'Localization', 'IL-4'),
#  ('ERK2', 'Localization', 'IL-4'),
#  ('IL-10', 'Gene_expression', 'IL-10'),
#  ('ERK1', 'Gene_expression', 'IL-10'),
#  ('ERK2', 'Gene_expression', 'IL-10'),
#  ('Eomes', 'Gene_expression', 'IFN-gamma'),
#  ('Runx3', 'Gene_expression', 'Eomes'),
#  ('Runx3', 'Gene_expression', 'perforin'),
#  ('T-bet', 'Gene_expression', 'perforin'),
#  ('Runx3', 'Gene_expression', 'IFN-gamma'),
#  ('Runx3', 'Gene_expression', 'granzyme B'),
#  ('Runx3', 'Gene_expression', 'Gzmb'),
#  ('T-bet', 'Transcription', 'Ifng'),
#  ('Eomes', 'Transcription', 'Prf1'),
#  ('HOIP', 'Binding', 'IKKgamma'),
#  ('CD40', 'Positive_regulation', 'CD80'),
#  ('CD40', 'Gene_expression', 'CD80'),
#  ('CD40', 'Positive_regulation', 'CD80'),
#  ('CD40', 'Positive_regulation', 'CD80'),
#  ('HOIP', 'Positive_regulation', 'CD80'),
#  ('HOIP', 'Positive_regulation', 'CD80'),
#  ('T-bet', 'Gene_expression', 'Perforin'),
#  ('T-bet', 'Gene_expression', 'granzyme B'),
#  ('T-bet', 'Transcription', 'perforin'),
#  ('T-bet', 'Negative_regulation', 'GzmB'),
#  ('Eo-VP16', 'Gene_expression', 'perforin'),
#  ('T-bet', 'Gene_expression', 'IFN-gamma'),
#  ('Eo-VP16', 'Transcription', 'GzmB'),
#  ('T-bet', 'Transcription', 'GzmB'),
#  ('T-bet', 'Gene_expression', 'perforin'),
#  ('Eomes', 'Gene_expression', 'perforin'),
#  ('T-bet', 'Gene_expression', 'granzyme B'),
#  ('Eomes', 'Gene_expression', 'granzyme B'),
#  ('T-bet', 'Gene_expression', 'IFN-gamma'),
#  ('Eomes', 'Gene_expression', 'IFN-gamma'),
#  ('Runx3', 'Gene_expression', 'IFN-gamma'),
#  ('Runx3', 'Gene_expression', 'TNF'),
#  ('Runx3', 'Gene_expression', 'IL-2'),
#  ('Runx3', 'Positive_regulation', 'Eomes'),
#  ('Runx3', 'Positive_regulation', 'Eomes'),
#  ('Runx3', 'Transcription', 'perforin'),
#  ('Eomes', 'Transcription', 'perforin'),
#  ('Runx3', 'Transcription', 'IFN-gamma'),
#  ('Eomes', 'Transcription', 'IFN-gamma'),
#  ('Runx3', 'Transcription', 'granzyme B'),
#  ('Eomes', 'Transcription', 'granzyme B'),
#  ('Runx3', 'Gene_expression', 'Eomes'),
#  ('Runx3', 'Gene_expression', 'perforin'),
#  ('Runx3', 'Gene_expression', 'granzyme B'),
#  ('Runx3', 'Gene_expression', 'IFN-gamma'),
#  ('Eo-VP16', 'Gene_expression', 'perforin'),
#  ('Runx3', 'Gene_expression', 'perforin'),
#  ('Eomes', 'Gene_expression', 'perforin'),
#  ('Runx3', 'Gene_expression', 'perforin'),
#  ('Eomes', 'Gene_expression', 'perforin'),
#  ('Runx3', 'Gene_expression', 'granzyme B'),
#  ('Eomes', 'Gene_expression', 'granzyme B'),
#  ('IL-12', 'Gene_expression', 'IFN-gamma'),
#  ('IL-12', 'Gene_expression', 'IL-10'),
#  ('IL-12', 'Gene_expression', 'IFN-gamma'),
#  ('IL-12', 'Gene_expression', 'IL-10'),
#  ('IL-12', 'Gene_expression', 'IL-10'),
#  ('IL-12', 'Gene_expression', 'IL-10'),
#  ('IL-12', 'Gene_expression', 'IL-10'),
#  ('TGF-beta', 'Gene_expression', 'IL-10'),
#  ('IL-12', 'Gene_expression', 'IL-10'),
#  ('IL-2', 'Gene_expression', 'IL-10'),
#  ('TGF-beta', 'Gene_expression', 'IL-10'),
#  ('IL-12', 'Transcription', 'Ifngamma'),
#  ('IL-12', 'Transcription', 'Ifngamma'),
#  ('IL-12', 'Transcription', 'Il10'),
#  ('IL-12', 'Gene_expression', 'Ifngamma'),
#  ('IL-12', 'Transcription', 'GATA-3'),
#  ('IL-12', 'Transcription', 'c-Maf'),
#  ('IL-12', 'Gene_expression', 'c-maf'),
#  ('c-maf', 'Positive_regulation', 'STAT4'),
#  ('MEK1', 'Gene_expression', 'Il10'),
#  ('MEK2', 'Gene_expression', 'Il10'),
#  ('MEK1', 'Gene_expression', 'c-maf'),
#  ('MEK2', 'Gene_expression', 'c-maf'),
#  ('MEK1', 'Gene_expression', 'T-bet'),
#  ('MEK2', 'Gene_expression', 'T-bet'),
#  ('MEK1', 'Gene_expression', 'RORgammat'),
#  ('MEK2', 'Gene_expression', 'RORgammat'),
#  ('Foxp3', 'Localization', 'Foxp3'),
#  ('Foxp3', 'Gene_expression', 'p65'),
#  ('deltaFKH', 'Gene_expression', 'p65'),
#  ('IFN-alpha', 'Gene_expression', 'IRF-4'),
#  ('IRF-4', 'Positive_regulation', 'IRF-4'),
#  ('c-Rel', 'Gene_expression', 'IRF-4'),
#  ('IRF-4', 'Binding', 'IRF-4'),
#  ('TRAF2', 'Binding', 'HOIL-1L-interacting protein'),
#  ('CD40', 'Positive_regulation', 'CD80'),
#  ('Runx3', 'Gene_expression', 'CD4'),
#  ('Foxp3', 'Gene_expression', 'Tax'),
#  ('deltaFKH', 'Positive_regulation', 'CREB'),
#  ('TRAF2', 'Binding', 'HOIL-1L interacting protein'),
#  ('CD40', 'Positive_regulation', 'CD80'),
#  ('Foxp3', 'Gene_expression', 'Tax'),
#  ('Foxp3', 'Transcription', 'Tax'),
#  ('deltaFKH', 'Gene_expression', 'Tax'),
#  ('Foxp3', 'Gene_expression', 'Tax'),
#  ('HOIP', 'Binding', 'CD40'),
#  ('TRAF2', 'Binding', 'HOIP'),
#  ('cIAP1', 'Binding', 'HOIP'),
#  ('cIAP2', 'Binding', 'HOIP'),
#  ('cIAP1', 'Binding', 'HOIP'),
#  ('cIAP2', 'Binding', 'HOIP'),
#  ('cIAP', 'Binding', 'HOIP'),
#  ('cIAP', 'Protein_modification', 'HOIP'),
#  ('HOIP', 'Binding', 'CD40'),
#  ('HOIP', 'Binding', 'TRAF2'),
#  ('HOIP', 'Binding', 'TRAF3'),
#  ('HOIP', 'Binding', 'cIAP1'),
#  ('HOIP', 'Binding', 'IKKgamma'),
#  ('HOIP', 'Binding', 'IKKgamma'),
#  ('IKKgamma', 'Protein_modification', 'IKKgamma')]

# %%
import nltk.data
import re
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
def get_sentence_list(text_file):
    sentence_list = []
    with open(text_file,'r') as reader:
        for i,line in enumerate(reader):
            temp_list = tokenizer.tokenize(line.strip())
            sentence_list.extend(temp_list)  
    return sentence_list

# %%
def get_entity_set(a1_file):
    with open(a1_file ,'r') as reader:
        entity_set = set([line.strip().split('\t')[2] for line in reader])
    return entity_set

# %%
def get_word_positions(string, word):
    position_list=[]
    for m in re.finditer(word, string):
        position_list.append((m.start(),m.end()))
    return position_list

# %%
def insert_entitiy_notation(text_file,a1_file):
    entity_dict = get_entity_dict(a1_file)
    entity_set = get_entity_set(a1_file)
    sentence_list = get_sentence_list(text_file)
    
    for sentence in sentence_list:
        for entity in entity_set:
            position_list = get_word_positions(sentence,entity)
            if len(position_list)>=1:
                print sentence, entity, position_list
